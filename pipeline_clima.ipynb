# %% [markdown]
# <a href="https://colab.research.google.com/github/Marta-repo/data-engineering-pyspark/blob/main/pipeline_clima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/marta-repo/data-engineering-pyspark.git
# Out:
# Cloning into 'data-engineering-pyspark'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 33 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 327.42 KiB | 8.62 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !ls
# Out:
# data-engineering-pyspark  sample_data

# %%
# %cd data-engineering-pyspark
# Out:
# /content/data-engineering-pyspark

# %%
import os

os.listdir("data")
# Out:
# ['mart', 'staging', 'raw']

# %%
# !pip install pyspark duckdb pandas requests pyarrow
from pyspark.sql import SparkSession
import requests
import pandas as pd
import duckdb
from pyspark.sql.functions import lit

spark = SparkSession.builder \
    .appName("pipeline_clima") \
    .getOrCreate()
